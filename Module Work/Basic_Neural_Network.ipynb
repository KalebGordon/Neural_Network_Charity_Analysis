# %%
# Import our dependencies
import pandas as pd
import matplotlib as plt
from sklearn.datasets import make_blobs
import sklearn as skl
import tensorflow as tf

# %%
# Generate dummy dataset
X, y = make_blobs(n_samples=1000, centers=2, n_features=2, random_state=78)

# Creating a DataFrame with the dummy data
df = pd.DataFrame(X, columns=["Feature 1", "Feature 2"])
df["Target"] = y

# Plotting the dummy data
df.plot.scatter(x="Feature 1", y="Feature 2", c="Target", colormap="winter")
# Out:
# <AxesSubplot:xlabel='Feature 1', ylabel='Feature 2'>

# %%
# Use sklearn to split dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create scaler instance
X_scaler = skl.preprocessing.StandardScaler()

# Fit the scaler
X_scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create the Keras Sequential model
nn_model = tf.keras.models.Sequential()

# %%
# Add our first Dense layer, including the input layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="relu", input_dim=2))

# %%
# Add the output layer that uses a probability activation function
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# %%
# Check the structure of the Sequential model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 3
#
#  dense_1 (Dense)             (None, 1)                 2
#
# =================================================================
# Total params: 5
# Trainable params: 5
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model to the training data
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 1s 1ms/step - loss: 0.4428 - accuracy: 0.9747
# Epoch 2/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4307 - accuracy: 0.9947
# Epoch 3/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4192 - accuracy: 0.9947
# Epoch 4/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4081 - accuracy: 0.9947
# Epoch 5/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3973 - accuracy: 0.9947
# Epoch 6/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3871 - accuracy: 0.9947
# Epoch 7/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3773 - accuracy: 0.9947
# Epoch 8/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3678 - accuracy: 0.9947
# Epoch 9/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3588 - accuracy: 0.9947
# Epoch 10/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3500 - accuracy: 0.9960
# Epoch 11/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3417 - accuracy: 0.9960
# Epoch 12/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3336 - accuracy: 0.9960
# Epoch 13/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3258 - accuracy: 0.9960
# Epoch 14/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3183 - accuracy: 0.9960
# Epoch 15/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3110 - accuracy: 0.9960
# Epoch 16/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3040 - accuracy: 0.9960
# Epoch 17/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2972 - accuracy: 0.9960
# Epoch 18/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2906 - accuracy: 0.9960
# Epoch 19/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2843 - accuracy: 0.9960
# Epoch 20/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2782 - accuracy: 0.9960
# Epoch 21/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2723 - accuracy: 0.9960
# Epoch 22/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2665 - accuracy: 0.9960
# Epoch 23/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2609 - accuracy: 0.9960
# Epoch 24/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2555 - accuracy: 0.9960
# Epoch 25/100
# 24/24 [==============================] - 0s 867us/step - loss: 0.2503 - accuracy: 0.9960
# Epoch 26/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2452 - accuracy: 0.9960
# Epoch 27/100
# 24/24 [==============================] - 0s 997us/step - loss: 0.2402 - accuracy: 0.9960
# Epoch 28/100
# 24/24 [==============================] - 0s 911us/step - loss: 0.2353 - accuracy: 0.9960
# Epoch 29/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2307 - accuracy: 0.9960
# Epoch 30/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2261 - accuracy: 0.9960
# Epoch 31/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2217 - accuracy: 0.9960
# Epoch 32/100
# 24/24 [==============================] - 0s 911us/step - loss: 0.2173 - accuracy: 0.9960
# Epoch 33/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2131 - accuracy: 0.9960
# Epoch 34/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2090 - accuracy: 0.9960
# Epoch 35/100
# 24/24 [==============================] - 0s 954us/step - loss: 0.2050 - accuracy: 0.9960
# Epoch 36/100
# 24/24 [==============================] - 0s 997us/step - loss: 0.2012 - accuracy: 0.9960
# Epoch 37/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1974 - accuracy: 0.9960
# Epoch 38/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1937 - accuracy: 0.9960
# Epoch 39/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1901 - accuracy: 0.9960
# Epoch 40/100
# 24/24 [==============================] - 0s 997us/step - loss: 0.1865 - accuracy: 0.9973
# Epoch 41/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1831 - accuracy: 0.9987
# Epoch 42/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1798 - accuracy: 1.0000
# Epoch 43/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1765 - accuracy: 1.0000
# Epoch 44/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1733 - accuracy: 1.0000
# Epoch 45/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1702 - accuracy: 1.0000
# Epoch 46/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1672 - accuracy: 1.0000
# Epoch 47/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1642 - accuracy: 1.0000
# Epoch 48/100
# 24/24 [==============================] - 0s 997us/step - loss: 0.1613 - accuracy: 1.0000
# Epoch 49/100
# 24/24 [==============================] - 0s 955us/step - loss: 0.1585 - accuracy: 1.0000
# Epoch 50/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1557 - accuracy: 1.0000
# Epoch 51/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1531 - accuracy: 1.0000
# Epoch 52/100
# 24/24 [==============================] - 0s 955us/step - loss: 0.1504 - accuracy: 1.0000
# Epoch 53/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1478 - accuracy: 1.0000
# Epoch 54/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1453 - accuracy: 1.0000
# Epoch 55/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1428 - accuracy: 1.0000
# Epoch 56/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1404 - accuracy: 1.0000
# Epoch 57/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1381 - accuracy: 1.0000
# Epoch 58/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1358 - accuracy: 1.0000
# Epoch 59/100
# 24/24 [==============================] - 0s 997us/step - loss: 0.1336 - accuracy: 1.0000
# Epoch 60/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1314 - accuracy: 1.0000
# Epoch 61/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1292 - accuracy: 1.0000
# Epoch 62/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1271 - accuracy: 1.0000
# Epoch 63/100
# 24/24 [==============================] - 0s 911us/step - loss: 0.1250 - accuracy: 1.0000
# Epoch 64/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1230 - accuracy: 1.0000
# Epoch 65/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1210 - accuracy: 1.0000
# Epoch 66/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1191 - accuracy: 1.0000
# Epoch 67/100
# 24/24 [==============================] - 0s 997us/step - loss: 0.1172 - accuracy: 1.0000
# Epoch 68/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1153 - accuracy: 1.0000
# Epoch 69/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1135 - accuracy: 1.0000
# Epoch 70/100
# 24/24 [==============================] - 0s 998us/step - loss: 0.1117 - accuracy: 1.0000
# Epoch 71/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1099 - accuracy: 1.0000
# Epoch 72/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1082 - accuracy: 1.0000
# Epoch 73/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1065 - accuracy: 1.0000
# Epoch 74/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1049 - accuracy: 1.0000
# Epoch 75/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1033 - accuracy: 1.0000
# Epoch 76/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1017 - accuracy: 1.0000
# Epoch 77/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1001 - accuracy: 1.0000
# Epoch 78/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0986 - accuracy: 1.0000
# Epoch 79/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0971 - accuracy: 1.0000
# Epoch 80/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0956 - accuracy: 1.0000
# Epoch 81/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0942 - accuracy: 1.0000
# Epoch 82/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0928 - accuracy: 1.0000
# Epoch 83/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0914 - accuracy: 1.0000
# Epoch 84/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0900 - accuracy: 1.0000
# Epoch 85/100
# 24/24 [==============================] - 0s 997us/step - loss: 0.0887 - accuracy: 1.0000
# Epoch 86/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0874 - accuracy: 1.0000
# Epoch 87/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0861 - accuracy: 1.0000
# Epoch 88/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0849 - accuracy: 1.0000
# Epoch 89/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0836 - accuracy: 1.0000
# Epoch 90/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0824 - accuracy: 1.0000
# Epoch 91/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0813 - accuracy: 1.0000
# Epoch 92/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0801 - accuracy: 1.0000
# Epoch 93/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0789 - accuracy: 1.0000
# Epoch 94/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0778 - accuracy: 1.0000
# Epoch 95/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0767 - accuracy: 1.0000
# Epoch 96/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0756 - accuracy: 1.0000
# Epoch 97/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0746 - accuracy: 1.0000
# Epoch 98/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0735 - accuracy: 1.0000
# Epoch 99/100
# 24/24 [==============================] - 0s 954us/step - loss: 0.0725 - accuracy: 1.0000
# Epoch 100/100
# 24/24 [==============================] - 0s 911us/step - loss: 0.0715 - accuracy: 1.0000

# %%
# Create a DataFrame containing training history
history_df = pd.DataFrame(fit_model.history, index=range(1,len(fit_model.history["loss"])+1))

# Plot the loss
history_df.plot(y="loss")
# Out:
# <AxesSubplot:>

# %%
# Plot the accuracy
history_df.plot(y="accuracy")
# Out:
# <AxesSubplot:>

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8/8 - 0s - loss: 0.0738 - accuracy: 1.0000 - 121ms/epoch - 15ms/step
# Loss: 0.07384604960680008, Accuracy: 1.0

# %%
# Predict the classification of a new set of blob data
new_X, new_Y = make_blobs(n_samples=10, centers=2, n_features=2, random_state=78)
new_X_scaled = X_scaler.transform(new_X)
(nn_model.predict(new_X_scaled) > 0.5).astype("int32")
# Out:
# 1/1 [==============================] - 0s 70ms/step
# array([[0],
#        [1],
#        [0],
#        [1],
#        [0],
#        [0],
#        [1],
#        [1],
#        [1],
#        [0]])

# %% [markdown]
# ## Non-Linear

# %%
from sklearn.datasets import make_moons

# Creating dummy nonlinear data
X_moons, y_moons = make_moons(n_samples=1000, noise=0.08, random_state=78)

# Transforming y_moons to a vertical vector
y_moons = y_moons.reshape(-1, 1)

# Creating a DataFrame to plot the nonlinear dummy data
df_moons = pd.DataFrame(X_moons, columns=["Feature 1", "Feature 2"])
df_moons["Target"] = y_moons

# Plot the nonlinear dummy data
df_moons.plot.scatter(x="Feature 1",y="Feature 2", c="Target",colormap="winter")
# Out:
# <AxesSubplot:xlabel='Feature 1', ylabel='Feature 2'>

# %%
# Create training and testing sets
X_moon_train, X_moon_test, y_moon_train, y_moon_test = train_test_split(
    X_moons, y_moons, random_state=78
)

# Create the scaler instance
X_moon_scaler = skl.preprocessing.StandardScaler()

# Fit the scaler
X_moon_scaler.fit(X_moon_train)

# Scale the data
X_moon_train_scaled = X_moon_scaler.transform(X_moon_train)
X_moon_test_scaled = X_moon_scaler.transform(X_moon_test)

# %%
# Training the model with the nonlinear data
model_moon = nn_model.fit(X_moon_train_scaled, y_moon_train, epochs=100, shuffle=True)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.1611 - accuracy: 0.4947
# Epoch 2/100
# 24/24 [==============================] - 0s 1ms/step - loss: 1.0162 - accuracy: 0.5147
# Epoch 3/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.9189 - accuracy: 0.5280
# Epoch 4/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8553 - accuracy: 0.5427
# Epoch 5/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.8085 - accuracy: 0.5587
# Epoch 6/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7721 - accuracy: 0.5773
# Epoch 7/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7421 - accuracy: 0.5867
# Epoch 8/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7168 - accuracy: 0.5973
# Epoch 9/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6955 - accuracy: 0.6107
# Epoch 10/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6762 - accuracy: 0.6213
# Epoch 11/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6592 - accuracy: 0.6320
# Epoch 12/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6438 - accuracy: 0.6440
# Epoch 13/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6288 - accuracy: 0.6573
# Epoch 14/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6155 - accuracy: 0.6613
# Epoch 15/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6027 - accuracy: 0.6693
# Epoch 16/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5902 - accuracy: 0.6733
# Epoch 17/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5784 - accuracy: 0.6853
# Epoch 18/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5671 - accuracy: 0.6907
# Epoch 19/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5567 - accuracy: 0.6960
# Epoch 20/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5465 - accuracy: 0.7027
# Epoch 21/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5367 - accuracy: 0.7053
# Epoch 22/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5274 - accuracy: 0.7120
# Epoch 23/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5187 - accuracy: 0.7173
# Epoch 24/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5099 - accuracy: 0.7213
# Epoch 25/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5012 - accuracy: 0.7267
# Epoch 26/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4927 - accuracy: 0.7347
# Epoch 27/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4842 - accuracy: 0.7400
# Epoch 28/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4755 - accuracy: 0.7427
# Epoch 29/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4670 - accuracy: 0.7480
# Epoch 30/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4581 - accuracy: 0.7507
# Epoch 31/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4492 - accuracy: 0.7600
# Epoch 32/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4405 - accuracy: 0.7653
# Epoch 33/100
# 24/24 [==============================] - 0s 997us/step - loss: 0.4319 - accuracy: 0.7707
# Epoch 34/100
# 24/24 [==============================] - 0s 997us/step - loss: 0.4236 - accuracy: 0.7760
# Epoch 35/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4155 - accuracy: 0.7787
# Epoch 36/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4073 - accuracy: 0.7880
# Epoch 37/100
# 24/24 [==============================] - 0s 954us/step - loss: 0.3991 - accuracy: 0.7947
# Epoch 38/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3909 - accuracy: 0.8000
# Epoch 39/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3830 - accuracy: 0.8040
# Epoch 40/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3758 - accuracy: 0.8080
# Epoch 41/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3683 - accuracy: 0.8107
# Epoch 42/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3613 - accuracy: 0.8173
# Epoch 43/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3545 - accuracy: 0.8213
# Epoch 44/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3480 - accuracy: 0.8307
# Epoch 45/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3419 - accuracy: 0.8360
# Epoch 46/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3363 - accuracy: 0.8400
# Epoch 47/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3314 - accuracy: 0.8440
# Epoch 48/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3268 - accuracy: 0.8480
# Epoch 49/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3228 - accuracy: 0.8493
# Epoch 50/100
# 24/24 [==============================] - 0s 997us/step - loss: 0.3194 - accuracy: 0.8507
# Epoch 51/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3163 - accuracy: 0.8547
# Epoch 52/100
# 24/24 [==============================] - 0s 913us/step - loss: 0.3135 - accuracy: 0.8573
# Epoch 53/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3111 - accuracy: 0.8600
# Epoch 54/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3088 - accuracy: 0.8667
# Epoch 55/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3068 - accuracy: 0.8667
# Epoch 56/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3049 - accuracy: 0.8667
# Epoch 57/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3031 - accuracy: 0.8680
# Epoch 58/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3014 - accuracy: 0.8693
# Epoch 59/100
# 24/24 [==============================] - 0s 954us/step - loss: 0.3000 - accuracy: 0.8733
# Epoch 60/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2985 - accuracy: 0.8733
# Epoch 61/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2972 - accuracy: 0.8760
# Epoch 62/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2958 - accuracy: 0.8760
# Epoch 63/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2945 - accuracy: 0.8787
# Epoch 64/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2933 - accuracy: 0.8787
# Epoch 65/100
# 24/24 [==============================] - 0s 997us/step - loss: 0.2921 - accuracy: 0.8800
# Epoch 66/100
# 24/24 [==============================] - 0s 954us/step - loss: 0.2910 - accuracy: 0.8800
# Epoch 67/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2899 - accuracy: 0.8813
# Epoch 68/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2889 - accuracy: 0.8813
# Epoch 69/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2879 - accuracy: 0.8840
# Epoch 70/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2869 - accuracy: 0.8840
# Epoch 71/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2859 - accuracy: 0.8853
# Epoch 72/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2850 - accuracy: 0.8867
# Epoch 73/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2841 - accuracy: 0.8880
# Epoch 74/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2833 - accuracy: 0.8867
# Epoch 75/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2825 - accuracy: 0.8853
# Epoch 76/100
# 24/24 [==============================] - 0s 934us/step - loss: 0.2817 - accuracy: 0.8867
# Epoch 77/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2809 - accuracy: 0.8867
# Epoch 78/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2801 - accuracy: 0.8867
# Epoch 79/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2793 - accuracy: 0.8867
# Epoch 80/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2786 - accuracy: 0.8853
# Epoch 81/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2779 - accuracy: 0.8840
# Epoch 82/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2773 - accuracy: 0.8840
# Epoch 83/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2767 - accuracy: 0.8853
# Epoch 84/100
# 24/24 [==============================] - 0s 998us/step - loss: 0.2760 - accuracy: 0.8867
# Epoch 85/100
# 24/24 [==============================] - 0s 998us/step - loss: 0.2754 - accuracy: 0.8867
# Epoch 86/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2748 - accuracy: 0.8867
# Epoch 87/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2744 - accuracy: 0.8880
# Epoch 88/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2737 - accuracy: 0.8880
# Epoch 89/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2732 - accuracy: 0.8880
# Epoch 90/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2728 - accuracy: 0.8893
# Epoch 91/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2722 - accuracy: 0.8920
# Epoch 92/100
# 24/24 [==============================] - 0s 997us/step - loss: 0.2718 - accuracy: 0.8907
# Epoch 93/100
# 24/24 [==============================] - 0s 997us/step - loss: 0.2713 - accuracy: 0.8893
# Epoch 94/100
# 24/24 [==============================] - 0s 997us/step - loss: 0.2709 - accuracy: 0.8880
# Epoch 95/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2704 - accuracy: 0.8880
# Epoch 96/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2700 - accuracy: 0.8893
# Epoch 97/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2695 - accuracy: 0.8893
# Epoch 98/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2691 - accuracy: 0.8907
# Epoch 99/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2688 - accuracy: 0.8907
# Epoch 100/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2684 - accuracy: 0.8893

# %%
# Create a DataFrame containing training history
history_df = pd.DataFrame(model_moon.history, index=range(1,len(model_moon.history["loss"])+1))

# Plot the loss
history_df.plot(y="loss")
# Out:
# <AxesSubplot:>

# %%
# Plot the accuracy
history_df.plot(y="accuracy")
# Out:
# <AxesSubplot:>

# %%
# Generate our new Sequential model
new_model = tf.keras.models.Sequential()

# %%
# Add the input and hidden layer
number_inputs = 2
number_hidden_nodes = 6

new_model.add(tf.keras.layers.Dense(units=number_hidden_nodes, activation="relu", input_dim=number_inputs))

# Add the output layer that uses a probability activation function
new_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# %%
# Compile the Sequential model together and customize metrics
new_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Fit the model to the training data
new_fit_model = new_model.fit(X_moon_train_scaled, y_moon_train, epochs=100, shuffle=True)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 1s 2ms/step - loss: 0.5162 - accuracy: 0.8880
# Epoch 2/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4931 - accuracy: 0.8880
# Epoch 3/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4696 - accuracy: 0.8867
# Epoch 4/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4457 - accuracy: 0.8853
# Epoch 5/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4226 - accuracy: 0.8853
# Epoch 6/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4007 - accuracy: 0.8853
# Epoch 7/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3799 - accuracy: 0.8853
# Epoch 8/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3616 - accuracy: 0.8853
# Epoch 9/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3452 - accuracy: 0.8853
# Epoch 10/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3309 - accuracy: 0.8867
# Epoch 11/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3187 - accuracy: 0.8867
# Epoch 12/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3085 - accuracy: 0.8867
# Epoch 13/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2995 - accuracy: 0.8867
# Epoch 14/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2923 - accuracy: 0.8867
# Epoch 15/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2862 - accuracy: 0.8867
# Epoch 16/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2810 - accuracy: 0.8867
# Epoch 17/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2766 - accuracy: 0.8880
# Epoch 18/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2730 - accuracy: 0.8893
# Epoch 19/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2700 - accuracy: 0.8920
# Epoch 20/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2676 - accuracy: 0.8920
# Epoch 21/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2653 - accuracy: 0.8920
# Epoch 22/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2635 - accuracy: 0.8920
# Epoch 23/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2620 - accuracy: 0.8920
# Epoch 24/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2607 - accuracy: 0.8920
# Epoch 25/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2596 - accuracy: 0.8933
# Epoch 26/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2584 - accuracy: 0.8933
# Epoch 27/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2577 - accuracy: 0.8920
# Epoch 28/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2569 - accuracy: 0.8933
# Epoch 29/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2562 - accuracy: 0.8933
# Epoch 30/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2557 - accuracy: 0.8947
# Epoch 31/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2552 - accuracy: 0.8947
# Epoch 32/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2548 - accuracy: 0.8933
# Epoch 33/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2543 - accuracy: 0.8947
# Epoch 34/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2539 - accuracy: 0.8933
# Epoch 35/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2536 - accuracy: 0.8947
# Epoch 36/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2533 - accuracy: 0.8933
# Epoch 37/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2530 - accuracy: 0.8960
# Epoch 38/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2526 - accuracy: 0.8960
# Epoch 39/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2524 - accuracy: 0.8960
# Epoch 40/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2520 - accuracy: 0.8960
# Epoch 41/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2518 - accuracy: 0.8960
# Epoch 42/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2516 - accuracy: 0.8960
# Epoch 43/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2513 - accuracy: 0.8973
# Epoch 44/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2511 - accuracy: 0.8960
# Epoch 45/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2509 - accuracy: 0.8973
# Epoch 46/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2506 - accuracy: 0.8960
# Epoch 47/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2505 - accuracy: 0.8960
# Epoch 48/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2503 - accuracy: 0.8973
# Epoch 49/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2500 - accuracy: 0.8973
# Epoch 50/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2499 - accuracy: 0.8973
# Epoch 51/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2496 - accuracy: 0.8973
# Epoch 52/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2495 - accuracy: 0.8973
# Epoch 53/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2492 - accuracy: 0.8973
# Epoch 54/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2490 - accuracy: 0.8973
# Epoch 55/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2489 - accuracy: 0.8973
# Epoch 56/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2487 - accuracy: 0.8973
# Epoch 57/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2484 - accuracy: 0.8973
# Epoch 58/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2482 - accuracy: 0.8973
# Epoch 59/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2484 - accuracy: 0.8973
# Epoch 60/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2477 - accuracy: 0.8973
# Epoch 61/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2475 - accuracy: 0.8973
# Epoch 62/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2473 - accuracy: 0.8973
# Epoch 63/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2473 - accuracy: 0.8973
# Epoch 64/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2469 - accuracy: 0.8973
# Epoch 65/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2467 - accuracy: 0.8973
# Epoch 66/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2465 - accuracy: 0.8973
# Epoch 67/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2463 - accuracy: 0.8973
# Epoch 68/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2461 - accuracy: 0.8973
# Epoch 69/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2459 - accuracy: 0.8973
# Epoch 70/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2457 - accuracy: 0.8973
# Epoch 71/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2456 - accuracy: 0.8973
# Epoch 72/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2455 - accuracy: 0.8973
# Epoch 73/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2450 - accuracy: 0.8973
# Epoch 74/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2449 - accuracy: 0.8973
# Epoch 75/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2446 - accuracy: 0.8973
# Epoch 76/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2445 - accuracy: 0.8973
# Epoch 77/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2441 - accuracy: 0.8973
# Epoch 78/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2438 - accuracy: 0.8973
# Epoch 79/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2434 - accuracy: 0.8973
# Epoch 80/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2432 - accuracy: 0.8973
# Epoch 81/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2428 - accuracy: 0.8973
# Epoch 82/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2425 - accuracy: 0.8973
# Epoch 83/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2421 - accuracy: 0.8973
# Epoch 84/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2418 - accuracy: 0.8973
# Epoch 85/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2415 - accuracy: 0.8973
# Epoch 86/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2412 - accuracy: 0.8973
# Epoch 87/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2409 - accuracy: 0.8987
# Epoch 88/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2405 - accuracy: 0.9000
# Epoch 89/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2401 - accuracy: 0.9000
# Epoch 90/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2396 - accuracy: 0.9000
# Epoch 91/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2394 - accuracy: 0.9000
# Epoch 92/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2388 - accuracy: 0.8987
# Epoch 93/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2385 - accuracy: 0.9000
# Epoch 94/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2382 - accuracy: 0.9000
# Epoch 95/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2376 - accuracy: 0.9013
# Epoch 96/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2374 - accuracy: 0.9027
# Epoch 97/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2368 - accuracy: 0.9000
# Epoch 98/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2364 - accuracy: 0.9000
# Epoch 99/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2359 - accuracy: 0.9013
# Epoch 100/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2353 - accuracy: 0.9013
